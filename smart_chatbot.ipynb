# %% [markdown]
# <a href="https://colab.research.google.com/github/presleyyyy/Presley-data-science/blob/main/smart_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
# !pip install newspaper3k
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 12.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 31.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=eea8adff202fc2b53f2f221fbf9804e1535e2fe615c94e7e2e8b9fe70cc0c59c
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=879b8417d4bb2f927ccda57db5198d94b371686a95f427333e4e378e23e1bcbc
# ...

# %%
#import the libraries
from newspaper import Article
import random
import string
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#import the libraries
import nltk  # Make sure nltk is imported before using it

#download the punkt package
nltk.download('punkt', quiet=True)
# Out:
# True

# %%
#import the libraries
import nltk  # Make sure nltk is imported before using it

#download the punkt package
nltk.download('punkt', quiet=True)
# Out:
# True

# %%
# Install the newspaper3k library
# !pip install newspaper3k

# Import the Article class
from newspaper import Article

#get the article
article = Article('https://www.mayoclinic.org/diseases-conditions/prostate-cancer/diagnosis-treatment/drc-20353093')
article.download()
article.parse()
article.nlp()
corpus = article.text

# %%
#print the articles text
print(corpus)
# Out:
# Diagnosis
#
# Get answers to the most frequently asked questions about prostate cancer from Mayo Clinic urologist Mitchell Humphreys, M.D.
#
# ...

# %%
# Install the newspaper3k library
# !pip install newspaper3k

# Import the Article class
from newspaper import Article

# Import nltk
import nltk

# Download the 'punkt' package
nltk.download('punkt')

#get the article
article = Article('https://www.mayoclinic.org/diseases-conditions/prostate-cancer/diagnosis-treatment/drc-20353093')
article.download()
article.parse()
article.nlp()
corpus = article.text

#print the articles text
print(corpus)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Diagnosis
#
# Get answers to the most frequently asked questions about prostate cancer from Mayo Clinic urologist Mitchell Humphreys, M.D.
#
# ...

# %%
# Install the newspaper3k library
# !pip install newspaper3k

# Import the Article class
from newspaper import Article

# Import nltk
import nltk

# Download the 'punkt' package
nltk.download('punkt')

#get the article
article = Article('https://www.mayoclinic.org/diseases-conditions/prostate-cancer/diagnosis-treatment/drc-20353093')
article.download()
article.parse()
article.nlp()
corpus = article.text

# Tokenize the corpus into sentences
sentence_list = nltk.sent_tokenize(corpus)  # Create the sentence_list variable

#print the list of sentences
print (sentence_list)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
#stemming
from nltk.stem import PorterStemmer, LancasterStemmer
porter_stemmer = PorterStemmer()
print (porter_stemmer.stem('running'))
print (porter_stemmer.stem('run'))
print (porter_stemmer.stem('runs'))
print (porter_stemmer.stem('runner'))
# Out:
# run
# run
# run
# runner

# %%
lancaster_stemmer = LancasterStemmer()
print (lancaster_stemmer.stem('running'))
print (lancaster_stemmer.stem('run'))
print (lancaster_stemmer.stem('runs'))
print (lancaster_stemmer.stem('runner'))
# Out:
# run
# run
# run
# run

# %%
#lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
print (lemmatizer.lemmatize('running'))
print (lemmatizer.lemmatize('run'))
print (lemmatizer.lemmatize('runs'))
print (lemmatizer.lemmatize('runner'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# running
# run
# run
# runner

# %%
# A function to return a random greeting response to a users greeting
def greeting_response(text):
  text = text.lower


  #Bots greeting response
  bot_greetings = ['goodday', 'hi', 'greetings', 'hello']
  #Users greeting
  user_greetings = ['hi', 'hey', 'hello', 'goodday', 'greetings', 'warm greetings']


  #if user's input is a greeting, return a randomly chosen greeting response
  for word in text.split():
    if word in user_greetings:
      return random.choice(bot_greetings)

# %%
def index_sort(list_var):
  length = len(list_var)
  list_index = list(range(0, length))

  x = list_var # Now list_var is defined within the function's scope
  for i in range(length):
      for j in range(length):
          if x[list_index[i]] > x[list_index[j]]:
              temp = list_index[i]
              list_index[i] = list_index[j]
              list_index[j] = temp
  return list_index

# %%
#create the bots response
def bot_response(user_input):
  user_input = user_input.lower
  sentence_list.append(user_input)
  bot_response = ''
  cv = CountVectorizer().fit_transform(sentence_list)
  similarity_scores = cosine_similarity(cv[-1], cv)
  similarity_scores_list = similarity_scores.flatten()
  index = index_sort(similarity_scores_list)
  index = index[1:]
  response_flag = 0
  j = 0
  for i in range(len(index)):
    if similarity_scores_list[index[i]] > 0.0:
      bot_response = bot_response + ' ' + sentence_list[index[i]]
      response_flag = 1
      j = j + 1
    if j > 2:
      break
    if response_flag == 0:
      bot_response = bot_response + ' ' + 'I am sorry, I do not understand you'
      sentence_list.remove(user_input)
      return bot_response

# %%
#start the chat
print('DOCTOR BOT: I AM DOCTOR BOT. I WILL ANSWER YOUR QUESTIONS ABOUT THE PROSTATE CANCER. IF YOU WANT TO EXIT, TYPE BYE!')
exit_list = ['exit', 'bye', 'quit', 'break']

# Import the random module
import random

# Import necessary modules from scikit-learn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Define index_sort function before it's called
def index_sort(list_var):
  length = len(list_var)
  list_index = list(range(0, length))

  x = list_var
  for i in range(length):
      for j in range(length):
          if x[list_index[i]] > x[list_index[j]]:
              temp = list_index[i]
              list_index[i] = list_index[j]
              list_index[j] = temp
  return list_index

# A function to return a random greeting response to a users greeting
def greeting_response(text): # Define the function in the same scope
  text = text.lower()


  #Bots greeting response
  bot_greetings = ['goodday', 'hi', 'greetings', 'hello']
  #Users greeting
  user_greetings = ['hi', 'hey', 'hello', 'goodday', 'greetings', 'warm greetings'] # Fix the missing closing quote here


  #if user's input is a greeting, return a randomly chosen greeting response
  for word in text.split():
    if word in user_greetings:
      return random.choice(bot_greetings)

#create the bots response # Define bot_response before it's called
def bot_response(user_input):
  user_input = user_input.lower() # Add parentheses to call the lower() method
  sentence_list.append(user_input) # Make sure sentence_list is defined somewhere
  bot_response = ''
  cv = CountVectorizer().fit_transform(sentence_list)
  similarity_scores = cosine_similarity(cv[-1], cv)
  similarity_scores_list = similarity_scores.flatten()
  index = index_sort(similarity_scores_list) # Now index_sort is available
  index = index[1:]
  response_flag = 0
  j = 0
  for i in range(len(index)):
    if similarity_scores_list[index[i]] > 0.0:
      bot_response = bot_response + ' ' + sentence_list[index[i]]
      response_flag = 1
      j = j + 1
    if j > 2:
      break
  # Ensure a response is always returned
  if response_flag == 0:
      bot_response = bot_response + ' ' + 'I am sorry, I do not understand you'
      sentence_list.remove(user_input)
  return bot_response # Return the response outside the conditional

while(True):
  user_input = input()
  if user_input.lower() in exit_list:
    print('DOCTOR BOT: BYE!') # Indent this line to match the level of the if statement
    break
  else:
    if greeting_response(user_input) is not None:
      print('DOCTOR BOT: ' + greeting_response(user_input))
    else:
      print('DOCTOR BOT: '+ bot_response(user_input)) # Call the bot_response function here
      #print(bot_response(user_input)) # Assuming bot_response is defined elsewhere
# Out:
# DOCTOR BOT: I AM DOCTOR BOT. I WILL ANSWER YOUR QUESTIONS ABOUT THE PROSTATE CANCER. IF YOU WANT TO EXIT, TYPE BYE!
# DOCTOR BOT: greetings
# DOCTOR BOT: hello
# DOCTOR BOT:  Not all prostate cancer is lethal and not all prostate cancer requires treatment. what is prostate cancer what is prostate cancer
# DOCTOR BOT:  causes of prostate cancer risk factors of prostate cancer Collecting a sample of prostate tissue.
